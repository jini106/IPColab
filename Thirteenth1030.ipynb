# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img=cv2.imread('/content/drive/MyDrive/IP/Images/Images/gsy.jpg')

print(img.shape)
gImg1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#plt.imshow(gImg1,cmap='gray')
cv2_imshow(gImg1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3071928432.py in <cell line: 0>()
#       1 img=cv2.imread('/content/drive/MyDrive/IP/Images/Images/gsy.jpg')
#       2
# ----> 3 print(img.shape)
#       4 gImg1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       5 #plt.imshow(gImg1,cmap='gray')
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
outimg = cv2.blur(gImg1, (7,7))
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
outimg = cv2.GaussianBlur(gImg1, (7,7), 5)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
outimg = cv2.medianBlur(gImg1, 7)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
outImage = gImg1.copy()
blurImage = cv2.GaussianBlur(outImage, (7,7), 1)
x = 380
y = 175
size = 10

for h in range(y, y+size):
  for w in range(x, x+size):
    outImage[h][w] = 255

cv2_imshow(outImage)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2761872428.py in <cell line: 0>()
#       7 for h in range(y, y+size):
#       8   for w in range(x, x+size):
# ----> 9     outImage[h][w] = 255
#      10
#      11 cv2_imshow(outImage)
#
# IndexError: index 380 is out of bounds for axis 0 with size 256

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/Images/lena256.jpg')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gImg1, cmap='gray')
cv2_imshow(gImg1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-928414072.py in <cell line: 0>()
#       1 img = cv2.imread('/content/gdrive/My Drive/Images/Images/lena256.jpg')
# ----> 2 print(img.shape)
#       3 gImg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#       4 #plt.imshow(gImg1, cmap='gray')
#       5 cv2_imshow(gImg1)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
outimg = cv2.GaussianBlur(gImg1, (7,7), 2)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
edgeimage = cv2.addWeighted(gImg1, 1, outimg, -1, 0)
cv2_imshow(edgeimage)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
unsharpimage = cv2.addWeighted(gImg1, 1, outimg, 1, 1)
cv2_imshow(unsharpimage)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel3 = np.ones((3,3), np.float32)/9
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] =  17/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
output = cv2.filter2D(gImg1, -1, kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
