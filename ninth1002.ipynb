# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np # 이미지는 기본적으로 2차원 배열이기 때문
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/Images/girl.jpg')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
cv2_imshow(gImg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([gImg], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
outImg = np.zeros(gImg.shape, dtype = 'uint8')

# %%
min = 0
max = 200

for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    if gImg[h, w] < min:
      outImg[h, w] = 0
    elif gImg[h, w] > max:
      outImg[h, w] = 255
    else:
      val = np.int32(gImg[h, w] - min) * 255
      val = np.int32(val / (max - min))
      outImg[h, w] = val

cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist2 = cv2.calcHist([outImg], [0], None, [256], [0, 256])
plt.plot(hist2)

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/Images/pentagon.bmp')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
cv2_imshow(gImg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([gImg], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
outImg = np.zeros(gImg.shape, dtype = 'uint8')

# %%
min = 70
max = 210

for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    if gImg[h, w] < min:
      outImg[h, w] = 0
    elif gImg[h, w] > max:
      outImg[h, w] = 255
    else:
      val = np.int32(gImg[h, w] - min) * 255
      val = np.int32(val / (max - min))
      outImg[h, w] = val

cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist2 = cv2.calcHist([outImg], [0], None, [256], [0, 256])
plt.plot(hist2)
